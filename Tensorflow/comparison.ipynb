# %%
import tensorflow as tf
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import tesorflow as tf
#       3 import time
#
# ModuleNotFoundError: No module named 'tesorflow'
